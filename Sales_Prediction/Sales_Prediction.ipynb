# %% [markdown]
# <a href="https://colab.research.google.com/github/DiwakarBasnet/Neural_Network/blob/main/Sales_Prediction/Sales_Prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Big Mart Sales Prediction
# -> Multilayer Perceptron (MLP)

# %%
# importing required libraries
import pandas as pd
import numpy as np
import sklearn
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# reading dataset
train_data = 'https://raw.githubusercontent.com/DiwakarBasnet/Neural_Network/main/Sales_Prediction/train_file.csv'
dataset = pd.read_csv(train_data)

# %% [markdown]
# ##1.Data Preprocessing

# %%
dataset.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# 2                       1999      Medium               Tier 1
# 3                       1998         NaN               Tier 3
# 4                       1987        High               Tier 3
#
#          Outlet_Type  Item_Outlet_Sales
# 0  Supermarket Type1          3735.1380
# 1  Supermarket Type2           443.4228
# 2  Supermarket Type1          2097.2700
# 3      Grocery Store           732.3800
# 4  Supermarket Type1           994.7052

# %%
# checking missing values in table
dataset.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
dataset.dtypes
# Out:
# Item_Identifier               object
# Item_Weight                  float64
# Item_Fat_Content              object
# Item_Visibility              float64
# Item_Type                     object
# Item_MRP                     float64
# Outlet_Identifier             object
# Outlet_Establishment_Year      int64
# Outlet_Size                   object
# Outlet_Location_Type          object
# Outlet_Type                   object
# Item_Outlet_Sales            float64
# dtype: object

# %% [markdown]
# ###I. Filling missing values

# %%
# filling missing values of continuous data with mean
dataset['Item_Weight'].fillna(dataset['Item_Weight'].mean(), inplace=True)

# filling missing values of categorical data with mode
dataset['Outlet_Size'].fillna(dataset['Outlet_Size'].mode()[0], inplace=True)

# %%
# checking missing values after imputation
dataset.isnull().sum()
# Out:
# Item_Identifier              0
# Item_Weight                  0
# Item_Fat_Content             0
# Item_Visibility              0
# Item_Type                    0
# Item_MRP                     0
# Outlet_Identifier            0
# Outlet_Establishment_Year    0
# Outlet_Size                  0
# Outlet_Location_Type         0
# Outlet_Type                  0
# Item_Outlet_Sales            0
# dtype: int64

# %% [markdown]
# ###II. Converting categorical data to numbers

# %%
print(dataset.Item_Fat_Content.value_counts())
print(dataset.Item_Type.value_counts())
print(dataset.Outlet_Size.value_counts())
print(dataset.Outlet_Location_Type.value_counts())
print(dataset.Outlet_Type.value_counts())
# Out:
# Low Fat    5089
# Regular    2889
# LF          316
# reg         117
# low fat     112
# Name: Item_Fat_Content, dtype: int64
# Fruits and Vegetables    1232
# Snack Foods              1200
# Household                 910
# Frozen Foods              856
# Dairy                     682
# Canned                    649
# Baking Goods              648
# Health and Hygiene        520
# Soft Drinks               445
# Meat                      425
# Breads                    251
# Hard Drinks               214
# Others                    169
# Starchy Foods             148
# Breakfast                 110
# Seafood                    64
# Name: Item_Type, dtype: int64
# Medium    5203
# Small     2388
# High       932
# Name: Outlet_Size, dtype: int64
# Tier 3    3350
# Tier 2    2785
# Tier 1    2388
# Name: Outlet_Location_Type, dtype: int64
# Supermarket Type1    5577
# Grocery Store        1083
# Supermarket Type3     935
# Supermarket Type2     928
# Name: Outlet_Type, dtype: int64

# %%
dataset['Item_Fat_Content'] = dataset['Item_Fat_Content'].map({'LF':0, 'Low Fat':0, 'low fat':0, 'Regular':1, 'reg':1})
dataset['Item_Type'] = dataset['Item_Type'].map({'Fruits and Vegetables':0, 'Snack Foods':1, 'Household':2, 'Frozen Foods':3, 'Dairy':4,
                                                 'Canned':5, 'Baking Goods':6, 'Health and Hygiene':7, 'Soft Drinks':8, 'Meat':9,
                                                 'Breads':10, 'Hard Drinks':11, 'Others':12, 'Starchy Foods':13, 'Breakfast':14, 'Seafood':15})
dataset['Outlet_Size'] = dataset['Outlet_Size'].map({'Small':0, 'Medium':1, 'High':2})
dataset['Outlet_Location_Type'] = dataset['Outlet_Location_Type'].map({'Tier 1':0, 'Tier 2':1, 'Tier 3':2})
dataset['Outlet_Type'] = dataset['Outlet_Type'].map({'Grocery Store':0, 'Supermarket Type1':1, 'Supermarket Type2':2, 'Supermarket Type3':3})

# %%
dataset.head()
# Out:
#   Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  Item_Type  \
# 0           FDA15         9.30                 0         0.016047          4
# 1           DRC01         5.92                 1         0.019278          8
# 2           FDN15        17.50                 0         0.016760          9
# 3           FDX07        19.20                 1         0.000000          0
# 4           NCD19         8.93                 0         0.000000          2
#
#    Item_MRP Outlet_Identifier  Outlet_Establishment_Year  Outlet_Size  \
# 0  249.8092            OUT049                       1999            1
# 1   48.2692            OUT018                       2009            1
# 2  141.6180            OUT049                       1999            1
# 3  182.0950            OUT010                       1998            1
# 4   53.8614            OUT013                       1987            2
#
#    Outlet_Location_Type  Outlet_Type  Item_Outlet_Sales
# 0                     0            1          3735.1380
# 1                     2            2           443.4228
# 2                     0            1          2097.2700
# 3                     2            0           732.3800
# 4                     2            1           994.7052

# %% [markdown]
# ###III. Normalization

# %%
# bringing the variables in the range of 0 to 1
for i in dataset.columns[1:6]:
  dataset[i] = (dataset[i] - dataset[i].min()) / (dataset[i].max() - dataset[i].min())

for i in dataset.columns[7:]:
  dataset[i] = (dataset[i] - dataset[i].min()) / (dataset[i].max() - dataset[i].min())

# %%
dataset.head()
# Out:
#   Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  Item_Type  \
# 0           FDA15     0.282525               0.0         0.048866   0.266667
# 1           DRC01     0.081274               1.0         0.058705   0.533333
# 2           FDN15     0.770765               0.0         0.051037   0.600000
# 3           FDX07     0.871986               1.0         0.000000   0.000000
# 4           NCD19     0.260494               0.0         0.000000   0.133333
#
#    Item_MRP Outlet_Identifier  Outlet_Establishment_Year  Outlet_Size  \
# 0  0.927507            OUT049                   0.583333          0.5
# 1  0.072068            OUT018                   1.000000          0.5
# 2  0.468288            OUT049                   0.583333          0.5
# 3  0.640093            OUT010                   0.541667          0.5
# 4  0.095805            OUT013                   0.083333          1.0
#
#    Outlet_Location_Type  Outlet_Type  Item_Outlet_Sales
# 0                   0.0     0.333333           0.283587
# 1                   1.0     0.666667           0.031419
# 2                   0.0     0.333333           0.158115
# 3                   1.0     0.000000           0.053555
# 4                   1.0     0.333333           0.073651

# %%
dataset.to_csv('normalized_train.csv', index=False)

# %%
data = pd.read_csv('normalized_train.csv')
# removing Item_Identifier and Outlet_Identifier
data = data.drop(['Item_Identifier', 'Outlet_Identifier'], axis=1)
data.head()
# Out:
#    Item_Weight  Item_Fat_Content  Item_Visibility  Item_Type  Item_MRP  \
# 0     0.282525               0.0         0.048866   0.266667  0.927507
# 1     0.081274               1.0         0.058705   0.533333  0.072068
# 2     0.770765               0.0         0.051037   0.600000  0.468288
# 3     0.871986               1.0         0.000000   0.000000  0.640093
# 4     0.260494               0.0         0.000000   0.133333  0.095805
#
#    Outlet_Establishment_Year  Outlet_Size  Outlet_Location_Type  Outlet_Type  \
# 0                   0.583333          0.5                   0.0     0.333333
# 1                   1.000000          0.5                   1.0     0.666667
# 2                   0.583333          0.5                   0.0     0.333333
# 3                   0.541667          0.5                   1.0     0.000000
# 4                   0.083333          1.0                   1.0     0.333333
#
#    Item_Outlet_Sales
# 0           0.283587
# 1           0.031419
# 2           0.158115
# 3           0.053555
# 4           0.073651

# %%
# storing all the features as X
X = data.drop('Item_Outlet_Sales', axis=1)
# storing target as y
y = data['Item_Outlet_Sales']
# shape of X and y
X.shape, y.shape
# Out:
# ((8523, 9), (8523,))

# %%
##### creating training and validation set #####
# random state to regenerate same train and validation set
# test size 0.2 will keep 20% data in validation and 80% train set

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, test_size=0.2)

(X_train.shape, y_train.shape), (X_test.shape, y_test.shape)
# Out:
# (((6818, 9), (6818,)), ((1705, 9), (1705,)))

# %% [markdown]
# ##2.Defining the architecture of model

# %%
import keras
import tensorflow as tf
from keras import backend as K
from keras.models import Sequential
from keras.layers import InputLayer, Dense

# %%
# defining input neurons
input_neurons = X_train.shape[1]
# defining output neurons
output_neurons = 1
# defining hidden layers and neurons in each layer
num_of_hidden_layers = 3
neuron_hidden_layer_1 = 30
neuron_hidden_layer_2 = 15
neuron_hidden_layer_3 = 5

# %%
from logging import INFO
model = Sequential()
model.add(InputLayer(input_shape=(input_neurons,)))
model.add(Dense(units=neuron_hidden_layer_1, activation='relu'))
model.add(Dense(units=neuron_hidden_layer_2, activation='relu'))
model.add(Dense(units=neuron_hidden_layer_3, activation='relu'))
model.add(Dense(units=output_neurons, activation='linear'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 30)                300
#
#  dense_1 (Dense)             (None, 15)                465
#
#  dense_2 (Dense)             (None, 5)                 80
#
#  dense_3 (Dense)             (None, 1)                 6
#
# =================================================================
# Total params: 851
# Trainable params: 851
# Non-trainable params: 0
# _________________________________________________________________

# %%
def root_mean_squared_error(y_true, y_pred):
        return K.sqrt(K.mean(K.square(y_pred - y_true))) 

##### Compiling the model #####
model.compile(loss = root_mean_squared_error, optimizer = 'Adam', metrics = ['mean_squared_error'])

# %% [markdown]
# ##3.Train model

# %%
model_history = model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=250)
# Out:
# Epoch 1/250
# 214/214 [==============================] - 1s 3ms/step - loss: 0.1092 - mean_squared_error: 0.0129 - val_loss: 0.0823 - val_mean_squared_error: 0.0071
# Epoch 2/250
# 214/214 [==============================] - 1s 2ms/step - loss: 0.0868 - mean_squared_error: 0.0078 - val_loss: 0.0796 - val_mean_squared_error: 0.0066
# Epoch 3/250
# 214/214 [==============================] - 1s 2ms/step - loss: 0.0852 - mean_squared_error: 0.0075 - val_loss: 0.0781 - val_mean_squared_error: 0.0064
# Epoch 4/250
# 214/214 [==============================] - 1s 3ms/step - loss: 0.0843 - mean_squared_error: 0.0073 - val_loss: 0.0781 - val_mean_squared_error: 0.0064
# Epoch 5/250
# 214/214 [==============================] - 1s 4ms/step - loss: 0.0840 - mean_squared_error: 0.0073 - val_loss: 0.0791 - val_mean_squared_error: 0.0065
# Epoch 6/250
# 214/214 [==============================] - 1s 3ms/step - loss: 0.0835 - mean_squared_error: 0.0072 - val_loss: 0.0770 - val_mean_squared_error: 0.0062
# Epoch 7/250
# 214/214 [==============================] - 1s 4ms/step - loss: 0.0838 - mean_squared_error: 0.0073 - val_loss: 0.0772 - val_mean_squared_error: 0.0063
# Epoch 8/250
# 214/214 [==============================] - 1s 4ms/step - loss: 0.0827 - mean_squared_error: 0.0071 - val_loss: 0.0767 - val_mean_squared_error: 0.0062
# Epoch 9/250
# 214/214 [==============================] - 1s 4ms/step - loss: 0.0827 - mean_squared_error: 0.0071 - val_loss: 0.0771 - val_mean_squared_error: 0.0062
# Epoch 10/250
# 214/214 [==============================] - 1s 4ms/step - loss: 0.0826 - mean_squared_error: 0.0071 - val_loss: 0.0773 - val_mean_squared_error: 0.0062
# Epoch 11/250
# 214/214 [==============================] - 1s 4ms/step - loss: 0.0827 - mean_squared_error: 0.0071 - val_loss: 0.0771 - val_mean_squared_error: 0.0063
# Epoch 12/250
# 214/214 [==============================] - 1s 5ms/step - loss: 0.0822 - mean_squared_error: 0.0070 - val_loss: 0.0808 - val_mean_squared_error: 0.0068
# Epoch 13/250
# 214/214 [==============================] - 1s 4ms/step - loss: 0.0824 - mean_squared_error: 0.0070 - val_loss: 0.0771 - val_mean_squared_error: 0.0062
# Epoch 14/250
# 214/214 [==============================] - 1s 4ms/step - loss: 0.0824 - mean_squared_error: 0.0070 - val_loss: 0.0764 - val_mean_squared_error: 0.0061
# Epoch 15/250
# 214/214 [==============================] - 1s 4ms/step - loss: 0.0820 - mean_squared_error: 0.0070 - val_loss: 0.0772 - val_mean_squared_error: 0.0062
# Epoch 16/250
# 214/214 [==============================] - 1s 4ms/step - loss: 0.0825 - mean_squared_error: 0.0070 - val_loss: 0.0766 - val_mean_squared_error: 0.0062
# Epoch 17/250
# 214/214 [==============================] - 1s 4ms/step - loss: 0.0822 - mean_squared_error: 0.0070 - val_loss: 0.0773 - val_mean_squared_error: 0.0063
# Epoch 18/250
# 214/214 [==============================] - 1s 5ms/step - loss: 0.0818 - mean_squared_error: 0.0069 - val_loss: 0.0791 - val_mean_squared_error: 0.0065
# Epoch 19/250
# 214/214 [==============================] - 1s 4ms/step - loss: 0.0826 - mean_squared_error: 0.0071 - val_loss: 0.0764 - val_mean_squared_error: 0.0061
# Epoch 20/250
# 214/214 [==============================] - 1s 6ms/step - loss: 0.0820 - mean_squared_error: 0.0070 - val_loss: 0.0770 - val_mean_squared_error: 0.0062
# Epoch 21/250
# 214/214 [==============================] - 1s 4ms/step - loss: 0.0823 - mean_squared_error: 0.0070 - val_loss: 0.0780 - val_mean_squared_error: 0.0063
# Epoch 22/250
# 214/214 [==============================] - 1s 5ms/step - loss: 0.0819 - mean_squared_error: 0.0070 - val_loss: 0.0775 - val_mean_squared_error: 0.0063
# Epoch 23/250
# 214/214 [==============================] - 1s 5ms/step - loss: 0.0821 - mean_squared_error: 0.0070 - val_loss: 0.0767 - val_mean_squared_error: 0.0062
# Epoch 24/250
# 214/214 [==============================] - 1s 5ms/step - loss: 0.0823 - mean_squared_error: 0.0070 - val_loss: 0.0764 - val_mean_squared_error: 0.0061
# Epoch 25/250
# 214/214 [==============================] - 1s 4ms/step - loss: 0.0817 - mean_squared_error: 0.0069 - val_loss: 0.0768 - val_mean_squared_error: 0.0062
# Epoch 26/250
# 214/214 [==============================] - 1s 4ms/step - loss: 0.0817 - mean_squared_error: 0.0069 - val_loss: 0.0761 - val_mean_squared_error: 0.0061
# Epoch 27/250
# 214/214 [==============================] - 1s 5ms/step - loss: 0.0818 - mean_squared_error: 0.0069 - val_loss: 0.0767 - val_mean_squared_error: 0.0062
# Epoch 28/250
# 214/214 [==============================] - 1s 3ms/step - loss: 0.0817 - mean_squared_error: 0.0069 - val_loss: 0.0764 - val_mean_squared_error: 0.0061
# Epoch 29/250
# 214/214 [==============================] - 1s 5ms/step - loss: 0.0820 - mean_squared_error: 0.0069 - val_loss: 0.0776 - val_mean_squared_error: 0.0063
# Epoch 30/250
# 214/214 [==============================] - 1s 4ms/step - loss: 0.0816 - mean_squared_error: 0.0069 - val_loss: 0.0764 - val_mean_squared_error: 0.0061
# Epoch 31/250
# 214/214 [==============================] - 0s 2ms/step - loss: 0.0819 - mean_squared_error: 0.0069 - val_loss: 0.0768 - val_mean_squared_error: 0.0062
# Epoch 32/250
# 214/214 [==============================] - 0s 2ms/step - loss: 0.0816 - mean_squared_error: 0.0069 - val_loss: 0.0785 - val_mean_squared_error: 0.0064
# Epoch 33/250
# 214/214 [==============================] - 0s 2ms/step - loss: 0.0819 - mean_squared_error: 0.0069 - val_loss: 0.0771 - val_mean_squared_error: 0.0063
# Epoch 34/250
# 214/214 [==============================] - 0s 2ms/step - loss: 0.0818 - mean_squared_error: 0.0069 - val_loss: 0.0762 - val_mean_squared_error: 0.0061
# Epoch 35/250
# 214/214 [==============================] - 0s 2ms/step - loss: 0.0813 - mean_squared_error: 0.0069 - val_loss: 0.0764 - val_mean_squared_error: 0.0061
# Epoch 36/250
# 214/214 [==============================] - 0s 2ms/step - loss: 0.0816 - mean_squared_error: 0.0069 - val_loss: 0.0760 - val_mean_squared_error: 0.0061
# Epoch 37/250
# 214/214 [==============================] - 0s 2ms/step - loss: 0.0813 - mean_squared_error: 0.0068 - val_loss: 0.0761 - val_mean_squared_error: 0.0061
# Epoch 38/250
# 214/214 [==============================] - 0s 2ms/step - loss: 0.0816 - mean_squared_error: 0.0069 - val_loss: 0.0765 - val_mean_squared_error: 0.0061
# Epoch 39/250
# 214/214 [==============================] - 0s 2ms/step - loss: 0.0815 - mean_squared_error: 0.0069 - val_loss: 0.0764 - val_mean_squared_error: 0.0061
# Epoch 40/250
# 214/214 [==============================] - 0s 2ms/step - loss: 0.0817 - mean_squared_error: 0.0069 - val_loss: 0.0769 - val_mean_squared_error: 0.0062
# Epoch 41/250
# 214/214 [==============================] - 0s 2ms/step - loss: 0.0810 - mean_squared_error: 0.0068 - val_loss: 0.0758 - val_mean_squared_error: 0.0060
# Epoch 42/250
# 214/214 [==============================] - 0s 2ms/step - loss: 0.0815 - mean_squared_error: 0.0069 - val_loss: 0.0767 - val_mean_squared_error: 0.0062
# Epoch 43/250
# 214/214 [==============================] - 1s 2ms/step - loss: 0.0813 - mean_squared_error: 0.0068 - val_loss: 0.0778 - val_mean_squared_error: 0.0063
# Epoch 44/250
# 214/214 [==============================] - 0s 2ms/step - loss: 0.0815 - mean_squared_error: 0.0069 - val_loss: 0.0767 - val_mean_squared_error: 0.0062
# Epoch 45/250
# 214/214 [==============================] - 0s 2ms/step - loss: 0.0816 - mean_squared_error: 0.0069 - val_loss: 0.0799 - val_mean_squared_error: 0.0066
# Epoch 46/250
# 214/214 [==============================] - 0s 2ms/step - loss: 0.0816 - mean_squared_error: 0.0069 - val_loss: 0.0771 - val_mean_squared_error: 0.0063
# Epoch 47/250
# 214/214 [==============================] - 0s 2ms/step - loss: 0.0816 - mean_squared_error: 0.0069 - val_loss: 0.0763 - val_mean_squared_error: 0.0061
# Epoch 48/250
# 214/214 [==============================] - 0s 2ms/step - loss: 0.0813 - mean_squared_error: 0.0068 - val_loss: 0.0765 - val_mean_squared_error: 0.0061
# Epoch 49/250
# 214/214 [==============================] - 0s 2ms/step - loss: 0.0811 - mean_squared_error: 0.0068 - val_loss: 0.0764 - val_mean_squared_error: 0.0061
# Epoch 50/250
# 214/214 [==============================] - 0s 2ms/step - loss: 0.0815 - mean_squared_error: 0.0069 - val_loss: 0.0766 - val_mean_squared_error: 0.0061
# Epoch 51/250
# 214/214 [==============================] - 0s 2ms/step - loss: 0.0815 - mean_squared_error: 0.0068 - val_loss: 0.0770 - val_mean_squared_error: 0.0062
# Epoch 52/250
# 214/214 [==============================] - 1s 3ms/step - loss: 0.0811 - mean_squared_error: 0.0068 - val_loss: 0.0783 - val_mean_squared_error: 0.0065
# Epoch 53/250
# 214/214 [==============================] - 0s 2ms/step - loss: 0.0813 - mean_squared_error: 0.0068 - val_loss: 0.0764 - val_mean_squared_error: 0.0061
# Epoch 54/250
# 214/214 [==============================] - 0s 2ms/step - loss: 0.0815 - mean_squared_error: 0.0069 - val_loss: 0.0764 - val_mean_squared_error: 0.0061
# Epoch 55/250
# 214/214 [==============================] - 0s 2ms/step - loss: 0.0810 - mean_squared_error: 0.0068 - val_loss: 0.0763 - val_mean_squared_error: 0.0061
# Epoch 56/250
# 214/214 [==============================] - 0s 2ms/step - loss: 0.0812 - mean_squared_error: 0.0068 - val_loss: 0.0775 - val_mean_squared_error: 0.0063
# Epoch 57/250
# 214/214 [==============================] - 0s 2ms/step - loss: 0.0807 - mean_squared_error: 0.0068 - val_loss: 0.0763 - val_mean_squared_error: 0.0061
# Epoch 58/250
# 214/214 [==============================] - 0s 2ms/step - loss: 0.0811 - mean_squared_error: 0.0068 - val_loss: 0.0774 - val_mean_squared_error: 0.0063
# Epoch 59/250
# 214/214 [==============================] - 0s 2ms/step - loss: 0.0809 - mean_squared_error: 0.0068 - val_loss: 0.0773 - val_mean_squared_error: 0.0062
# Epoch 60/250
# 214/214 [==============================] - 0s 2ms/step - loss: 0.0811 - mean_squared_error: 0.0068 - val_loss: 0.0768 - val_mean_squared_error: 0.0062
# Epoch 61/250
# 214/214 [==============================] - 0s 2ms/step - loss: 0.0810 - mean_squared_error: 0.0068 - val_loss: 0.0766 - val_mean_squared_error: 0.0062
# Epoch 62/250
# 214/214 [==============================] - 0s 2ms/step - loss: 0.0809 - mean_squared_error: 0.0068 - val_loss: 0.0765 - val_mean_squared_error: 0.0061
# Epoch 63/250
# 214/214 [==============================] - 0s 2ms/step - loss: 0.0812 - mean_squared_error: 0.0068 - val_loss: 0.0763 - val_mean_squared_error: 0.0061
# Epoch 64/250
# 214/214 [==============================] - 0s 2ms/step - loss: 0.0807 - mean_squared_error: 0.0068 - val_loss: 0.0781 - val_mean_squared_error: 0.0064
# Epoch 65/250
# 214/214 [==============================] - 0s 2ms/step - loss: 0.0805 - mean_squared_error: 0.0068 - val_loss: 0.0766 - val_mean_squared_error: 0.0061
# Epoch 66/250
# 214/214 [==============================] - 0s 2ms/step - loss: 0.0809 - mean_squared_error: 0.0068 - val_loss: 0.0766 - val_mean_squared_error: 0.0061
# Epoch 67/250
# 214/214 [==============================] - 0s 2ms/step - loss: 0.0811 - mean_squared_error: 0.0068 - val_loss: 0.0771 - val_mean_squared_error: 0.0063
# Epoch 68/250
# 214/214 [==============================] - 0s 2ms/step - loss: 0.0811 - mean_squared_error: 0.0068 - val_loss: 0.0770 - val_mean_squared_error: 0.0062
# Epoch 69/250
# 214/214 [==============================] - 0s 2ms/step - loss: 0.0809 - mean_squared_error: 0.0068 - val_loss: 0.0770 - val_mean_squared_error: 0.0062
# Epoch 70/250
# 214/214 [==============================] - 0s 2ms/step - loss: 0.0808 - mean_squared_error: 0.0068 - val_loss: 0.0770 - val_mean_squared_error: 0.0062
# Epoch 71/250
# 214/214 [==============================] - 0s 2ms/step - loss: 0.0811 - mean_squared_error: 0.0068 - val_loss: 0.0768 - val_mean_squared_error: 0.0062
# Epoch 72/250
# 214/214 [==============================] - 1s 3ms/step - loss: 0.0809 - mean_squared_error: 0.0068 - val_loss: 0.0769 - val_mean_squared_error: 0.0062
# Epoch 73/250
# 214/214 [==============================] - 1s 5ms/step - loss: 0.0810 - mean_squared_error: 0.0068 - val_loss: 0.0768 - val_mean_squared_error: 0.0062
# Epoch 74/250
# 214/214 [==============================] - 1s 4ms/step - loss: 0.0810 - mean_squared_error: 0.0068 - val_loss: 0.0775 - val_mean_squared_error: 0.0063
# Epoch 75/250
# 214/214 [==============================] - 1s 4ms/step - loss: 0.0813 - mean_squared_error: 0.0068 - val_loss: 0.0765 - val_mean_squared_error: 0.0061
# Epoch 76/250
# 214/214 [==============================] - 1s 4ms/step - loss: 0.0805 - mean_squared_error: 0.0067 - val_loss: 0.0772 - val_mean_squared_error: 0.0063
# Epoch 77/250
# 214/214 [==============================] - 1s 4ms/step - loss: 0.0809 - mean_squared_error: 0.0068 - val_loss: 0.0766 - val_mean_squared_error: 0.0061
# Epoch 78/250
# 214/214 [==============================] - 1s 5ms/step - loss: 0.0807 - mean_squared_error: 0.0068 - val_loss: 0.0774 - val_mean_squared_error: 0.0062
# Epoch 79/250
# 214/214 [==============================] - 1s 5ms/step - loss: 0.0813 - mean_squared_error: 0.0068 - val_loss: 0.0803 - val_mean_squared_error: 0.0067
# Epoch 80/250
# 214/214 [==============================] - 1s 5ms/step - loss: 0.0811 - mean_squared_error: 0.0068 - val_loss: 0.0769 - val_mean_squared_error: 0.0062
# Epoch 81/250
# 214/214 [==============================] - 1s 5ms/step - loss: 0.0807 - mean_squared_error: 0.0067 - val_loss: 0.0767 - val_mean_squared_error: 0.0062
# Epoch 82/250
# 214/214 [==============================] - 1s 5ms/step - loss: 0.0807 - mean_squared_error: 0.0068 - val_loss: 0.0780 - val_mean_squared_error: 0.0064
# Epoch 83/250
# 214/214 [==============================] - 1s 4ms/step - loss: 0.0810 - mean_squared_error: 0.0068 - val_loss: 0.0777 - val_mean_squared_error: 0.0063
# Epoch 84/250
# 214/214 [==============================] - 1s 4ms/step - loss: 0.0808 - mean_squared_error: 0.0068 - val_loss: 0.0764 - val_mean_squared_error: 0.0061
# Epoch 85/250
# 214/214 [==============================] - 1s 5ms/step - loss: 0.0807 - mean_squared_error: 0.0067 - val_loss: 0.0769 - val_mean_squared_error: 0.0062
# Epoch 86/250
# 214/214 [==============================] - 1s 4ms/step - loss: 0.0808 - mean_squared_error: 0.0067 - val_loss: 0.0773 - val_mean_squared_error: 0.0063
# Epoch 87/250
# 214/214 [==============================] - 1s 5ms/step - loss: 0.0806 - mean_squared_error: 0.0067 - val_loss: 0.0772 - val_mean_squared_error: 0.0063
# Epoch 88/250
# 214/214 [==============================] - 1s 5ms/step - loss: 0.0808 - mean_squared_error: 0.0068 - val_loss: 0.0769 - val_mean_squared_error: 0.0062
# Epoch 89/250
# 214/214 [==============================] - 1s 4ms/step - loss: 0.0809 - mean_squared_error: 0.0068 - val_loss: 0.0776 - val_mean_squared_error: 0.0063
# Epoch 90/250
# 214/214 [==============================] - 1s 5ms/step - loss: 0.0808 - mean_squared_error: 0.0067 - val_loss: 0.0789 - val_mean_squared_error: 0.0065
# Epoch 91/250
# 214/214 [==============================] - 1s 5ms/step - loss: 0.0806 - mean_squared_error: 0.0067 - val_loss: 0.0773 - val_mean_squared_error: 0.0062
# Epoch 92/250
# 214/214 [==============================] - 1s 4ms/step - loss: 0.0802 - mean_squared_error: 0.0067 - val_loss: 0.0795 - val_mean_squared_error: 0.0066
# Epoch 93/250
# 214/214 [==============================] - 1s 4ms/step - loss: 0.0806 - mean_squared_error: 0.0067 - val_loss: 0.0798 - val_mean_squared_error: 0.0066
# Epoch 94/250
# 214/214 [==============================] - 1s 4ms/step - loss: 0.0803 - mean_squared_error: 0.0067 - val_loss: 0.0775 - val_mean_squared_error: 0.0063
# Epoch 95/250
# 214/214 [==============================] - 1s 3ms/step - loss: 0.0806 - mean_squared_error: 0.0067 - val_loss: 0.0775 - val_mean_squared_error: 0.0063
# Epoch 96/250
# 214/214 [==============================] - 0s 2ms/step - loss: 0.0807 - mean_squared_error: 0.0067 - val_loss: 0.0777 - val_mean_squared_error: 0.0063
# Epoch 97/250
# 214/214 [==============================] - 0s 2ms/step - loss: 0.0807 - mean_squared_error: 0.0068 - val_loss: 0.0774 - val_mean_squared_error: 0.0062
# Epoch 98/250
# 214/214 [==============================] - 0s 2ms/step - loss: 0.0806 - mean_squared_error: 0.0067 - val_loss: 0.0769 - val_mean_squared_error: 0.0062
# Epoch 99/250
# 214/214 [==============================] - 0s 2ms/step - loss: 0.0803 - mean_squared_error: 0.0067 - val_loss: 0.0781 - val_mean_squared_error: 0.0064
# Epoch 100/250
# 214/214 [==============================] - 0s 2ms/step - loss: 0.0805 - mean_squared_error: 0.0067 - val_loss: 0.0773 - val_mean_squared_error: 0.0063
# Epoch 101/250
# 214/214 [==============================] - 0s 2ms/step - loss: 0.0802 - mean_squared_error: 0.0067 - val_loss: 0.0771 - val_mean_squared_error: 0.0062
# Epoch 102/250
# 214/214 [==============================] - 0s 2ms/step - loss: 0.0801 - mean_squared_error: 0.0067 - val_loss: 0.0777 - val_mean_squared_error: 0.0063
# Epoch 103/250
# 214/214 [==============================] - 0s 2ms/step - loss: 0.0804 - mean_squared_error: 0.0067 - val_loss: 0.0788 - val_mean_squared_error: 0.0065
# Epoch 104/250
# 214/214 [==============================] - 0s 2ms/step - loss: 0.0808 - mean_squared_error: 0.0067 - val_loss: 0.0780 - val_mean_squared_error: 0.0064
# Epoch 105/250
# 214/214 [==============================] - 0s 2ms/step - loss: 0.0804 - mean_squared_error: 0.0067 - val_loss: 0.0780 - val_mean_squared_error: 0.0063
# Epoch 106/250
# 214/214 [==============================] - 0s 2ms/step - loss: 0.0803 - mean_squared_error: 0.0067 - val_loss: 0.0772 - val_mean_squared_error: 0.0062
# Epoch 107/250
# 214/214 [==============================] - 0s 2ms/step - loss: 0.0800 - mean_squared_error: 0.0067 - val_loss: 0.0777 - val_mean_squared_error: 0.0063
# Epoch 108/250
# 214/214 [==============================] - 0s 2ms/step - loss: 0.0805 - mean_squared_error: 0.0067 - val_loss: 0.0785 - val_mean_squared_error: 0.0065
# Epoch 109/250
# 214/214 [==============================] - 0s 2ms/step - loss: 0.0803 - mean_squared_error: 0.0067 - val_loss: 0.0783 - val_mean_squared_error: 0.0064
# Epoch 110/250
# 214/214 [==============================] - 0s 2ms/step - loss: 0.0803 - mean_squared_error: 0.0067 - val_loss: 0.0780 - val_mean_squared_error: 0.0063
# Epoch 111/250
# 214/214 [==============================] - 0s 2ms/step - loss: 0.0801 - mean_squared_error: 0.0067 - val_loss: 0.0772 - val_mean_squared_error: 0.0062
# Epoch 112/250
# 214/214 [==============================] - 0s 2ms/step - loss: 0.0802 - mean_squared_error: 0.0067 - val_loss: 0.0773 - val_mean_squared_error: 0.0062
# Epoch 113/250
# 214/214 [==============================] - 0s 2ms/step - loss: 0.0803 - mean_squared_error: 0.0067 - val_loss: 0.0790 - val_mean_squared_error: 0.0065
# Epoch 114/250
# 214/214 [==============================] - 0s 2ms/step - loss: 0.0806 - mean_squared_error: 0.0067 - val_loss: 0.0773 - val_mean_squared_error: 0.0062
# Epoch 115/250
# 214/214 [==============================] - 0s 2ms/step - loss: 0.0802 - mean_squared_error: 0.0067 - val_loss: 0.0771 - val_mean_squared_error: 0.0062
# Epoch 116/250
# 214/214 [==============================] - 0s 2ms/step - loss: 0.0801 - mean_squared_error: 0.0066 - val_loss: 0.0775 - val_mean_squared_error: 0.0063
# Epoch 117/250
# 214/214 [==============================] - 0s 2ms/step - loss: 0.0803 - mean_squared_error: 0.0067 - val_loss: 0.0774 - val_mean_squared_error: 0.0063
# Epoch 118/250
# 214/214 [==============================] - 0s 2ms/step - loss: 0.0803 - mean_squared_error: 0.0067 - val_loss: 0.0774 - val_mean_squared_error: 0.0063
# Epoch 119/250
# 214/214 [==============================] - 0s 2ms/step - loss: 0.0802 - mean_squared_error: 0.0066 - val_loss: 0.0775 - val_mean_squared_error: 0.0063
# Epoch 120/250
# 214/214 [==============================] - 0s 2ms/step - loss: 0.0801 - mean_squared_error: 0.0066 - val_loss: 0.0778 - val_mean_squared_error: 0.0064
# Epoch 121/250
# 214/214 [==============================] - 0s 2ms/step - loss: 0.0802 - mean_squared_error: 0.0066 - val_loss: 0.0773 - val_mean_squared_error: 0.0063
# Epoch 122/250
# 214/214 [==============================] - 0s 2ms/step - loss: 0.0802 - mean_squared_error: 0.0067 - val_loss: 0.0772 - val_mean_squared_error: 0.0062
# Epoch 123/250
# 214/214 [==============================] - 0s 2ms/step - loss: 0.0801 - mean_squared_error: 0.0066 - val_loss: 0.0774 - val_mean_squared_error: 0.0063
# Epoch 124/250
# 214/214 [==============================] - 0s 2ms/step - loss: 0.0801 - mean_squared_error: 0.0066 - val_loss: 0.0772 - val_mean_squared_error: 0.0062
# Epoch 125/250
# 214/214 [==============================] - 0s 2ms/step - loss: 0.0797 - mean_squared_error: 0.0066 - val_loss: 0.0772 - val_mean_squared_error: 0.0062
# Epoch 126/250
# 214/214 [==============================] - 0s 2ms/step - loss: 0.0801 - mean_squared_error: 0.0067 - val_loss: 0.0772 - val_mean_squared_error: 0.0062
# Epoch 127/250
# 214/214 [==============================] - 0s 2ms/step - loss: 0.0798 - mean_squared_error: 0.0066 - val_loss: 0.0777 - val_mean_squared_error: 0.0063
# Epoch 128/250
# 214/214 [==============================] - 0s 2ms/step - loss: 0.0804 - mean_squared_error: 0.0067 - val_loss: 0.0772 - val_mean_squared_error: 0.0062
# Epoch 129/250
# 214/214 [==============================] - 0s 2ms/step - loss: 0.0798 - mean_squared_error: 0.0066 - val_loss: 0.0774 - val_mean_squared_error: 0.0063
# Epoch 130/250
# 214/214 [==============================] - 0s 2ms/step - loss: 0.0798 - mean_squared_error: 0.0066 - val_loss: 0.0779 - val_mean_squared_error: 0.0063
# Epoch 131/250
# 214/214 [==============================] - 0s 2ms/step - loss: 0.0802 - mean_squared_error: 0.0066 - val_loss: 0.0776 - val_mean_squared_error: 0.0063
# Epoch 132/250
# 214/214 [==============================] - 0s 2ms/step - loss: 0.0797 - mean_squared_error: 0.0066 - val_loss: 0.0781 - val_mean_squared_error: 0.0063
# Epoch 133/250
# 214/214 [==============================] - 0s 2ms/step - loss: 0.0797 - mean_squared_error: 0.0066 - val_loss: 0.0774 - val_mean_squared_error: 0.0063
# Epoch 134/250
# 214/214 [==============================] - 0s 2ms/step - loss: 0.0799 - mean_squared_error: 0.0066 - val_loss: 0.0778 - val_mean_squared_error: 0.0063
# Epoch 135/250
# 214/214 [==============================] - 0s 2ms/step - loss: 0.0800 - mean_squared_error: 0.0066 - val_loss: 0.0772 - val_mean_squared_error: 0.0062
# Epoch 136/250
# 214/214 [==============================] - 0s 2ms/step - loss: 0.0797 - mean_squared_error: 0.0066 - val_loss: 0.0772 - val_mean_squared_error: 0.0062
# Epoch 137/250
# 214/214 [==============================] - 0s 2ms/step - loss: 0.0800 - mean_squared_error: 0.0066 - val_loss: 0.0793 - val_mean_squared_error: 0.0065
# Epoch 138/250
# 214/214 [==============================] - 0s 2ms/step - loss: 0.0799 - mean_squared_error: 0.0066 - val_loss: 0.0777 - val_mean_squared_error: 0.0063
# Epoch 139/250
# 214/214 [==============================] - 0s 2ms/step - loss: 0.0801 - mean_squared_error: 0.0066 - val_loss: 0.0788 - val_mean_squared_error: 0.0065
# Epoch 140/250
# 214/214 [==============================] - 0s 2ms/step - loss: 0.0795 - mean_squared_error: 0.0066 - val_loss: 0.0771 - val_mean_squared_error: 0.0062
# Epoch 141/250
# 214/214 [==============================] - 0s 2ms/step - loss: 0.0795 - mean_squared_error: 0.0066 - val_loss: 0.0773 - val_mean_squared_error: 0.0062
# Epoch 142/250
# 214/214 [==============================] - 0s 2ms/step - loss: 0.0800 - mean_squared_error: 0.0066 - val_loss: 0.0774 - val_mean_squared_error: 0.0063
# Epoch 143/250
# 214/214 [==============================] - 0s 2ms/step - loss: 0.0796 - mean_squared_error: 0.0065 - val_loss: 0.0774 - val_mean_squared_error: 0.0062
# Epoch 144/250
# 214/214 [==============================] - 0s 2ms/step - loss: 0.0795 - mean_squared_error: 0.0066 - val_loss: 0.0773 - val_mean_squared_error: 0.0063
# Epoch 145/250
# 214/214 [==============================] - 0s 2ms/step - loss: 0.0796 - mean_squared_error: 0.0066 - val_loss: 0.0780 - val_mean_squared_error: 0.0063
# Epoch 146/250
# 214/214 [==============================] - 0s 2ms/step - loss: 0.0795 - mean_squared_error: 0.0065 - val_loss: 0.0777 - val_mean_squared_error: 0.0063
# Epoch 147/250
# 214/214 [==============================] - 0s 2ms/step - loss: 0.0795 - mean_squared_error: 0.0066 - val_loss: 0.0777 - val_mean_squared_error: 0.0063
# Epoch 148/250
# 214/214 [==============================] - 0s 2ms/step - loss: 0.0797 - mean_squared_error: 0.0066 - val_loss: 0.0800 - val_mean_squared_error: 0.0066
# Epoch 149/250
# 214/214 [==============================] - 0s 2ms/step - loss: 0.0793 - mean_squared_error: 0.0065 - val_loss: 0.0780 - val_mean_squared_error: 0.0064
# Epoch 150/250
# 214/214 [==============================] - 0s 2ms/step - loss: 0.0794 - mean_squared_error: 0.0065 - val_loss: 0.0777 - val_mean_squared_error: 0.0063
# Epoch 151/250
# 214/214 [==============================] - 0s 2ms/step - loss: 0.0796 - mean_squared_error: 0.0066 - val_loss: 0.0778 - val_mean_squared_error: 0.0063
# Epoch 152/250
# 214/214 [==============================] - 0s 2ms/step - loss: 0.0799 - mean_squared_error: 0.0066 - val_loss: 0.0795 - val_mean_squared_error: 0.0066
# Epoch 153/250
# 214/214 [==============================] - 0s 2ms/step - loss: 0.0795 - mean_squared_error: 0.0066 - val_loss: 0.0775 - val_mean_squared_error: 0.0063
# Epoch 154/250
# 214/214 [==============================] - 0s 2ms/step - loss: 0.0795 - mean_squared_error: 0.0065 - val_loss: 0.0782 - val_mean_squared_error: 0.0064
# Epoch 155/250
# 214/214 [==============================] - 0s 2ms/step - loss: 0.0796 - mean_squared_error: 0.0066 - val_loss: 0.0774 - val_mean_squared_error: 0.0063
# Epoch 156/250
# 214/214 [==============================] - 0s 2ms/step - loss: 0.0796 - mean_squared_error: 0.0065 - val_loss: 0.0826 - val_mean_squared_error: 0.0070
# Epoch 157/250
# 214/214 [==============================] - 0s 2ms/step - loss: 0.0798 - mean_squared_error: 0.0066 - val_loss: 0.0778 - val_mean_squared_error: 0.0063
# Epoch 158/250
# 214/214 [==============================] - 0s 2ms/step - loss: 0.0797 - mean_squared_error: 0.0066 - val_loss: 0.0775 - val_mean_squared_error: 0.0063
# Epoch 159/250
# 214/214 [==============================] - 0s 2ms/step - loss: 0.0795 - mean_squared_error: 0.0065 - val_loss: 0.0782 - val_mean_squared_error: 0.0064
# Epoch 160/250
# 214/214 [==============================] - 0s 2ms/step - loss: 0.0800 - mean_squared_error: 0.0066 - val_loss: 0.0778 - val_mean_squared_error: 0.0063
# Epoch 161/250
# 214/214 [==============================] - 0s 2ms/step - loss: 0.0794 - mean_squared_error: 0.0065 - val_loss: 0.0779 - val_mean_squared_error: 0.0064
# Epoch 162/250
# 214/214 [==============================] - 0s 2ms/step - loss: 0.0798 - mean_squared_error: 0.0066 - val_loss: 0.0778 - val_mean_squared_error: 0.0063
# Epoch 163/250
# 214/214 [==============================] - 0s 2ms/step - loss: 0.0792 - mean_squared_error: 0.0065 - val_loss: 0.0779 - val_mean_squared_error: 0.0063
# Epoch 164/250
# 214/214 [==============================] - 0s 2ms/step - loss: 0.0797 - mean_squared_error: 0.0066 - val_loss: 0.0780 - val_mean_squared_error: 0.0064
# Epoch 165/250
# 214/214 [==============================] - 0s 2ms/step - loss: 0.0794 - mean_squared_error: 0.0065 - val_loss: 0.0778 - val_mean_squared_error: 0.0063
# Epoch 166/250
# 214/214 [==============================] - 0s 2ms/step - loss: 0.0795 - mean_squared_error: 0.0065 - val_loss: 0.0781 - val_mean_squared_error: 0.0064
# Epoch 167/250
# 214/214 [==============================] - 0s 2ms/step - loss: 0.0796 - mean_squared_error: 0.0065 - val_loss: 0.0778 - val_mean_squared_error: 0.0063
# Epoch 168/250
# 214/214 [==============================] - 0s 2ms/step - loss: 0.0799 - mean_squared_error: 0.0066 - val_loss: 0.0789 - val_mean_squared_error: 0.0065
# Epoch 169/250
# 214/214 [==============================] - 0s 2ms/step - loss: 0.0796 - mean_squared_error: 0.0066 - val_loss: 0.0777 - val_mean_squared_error: 0.0063
# Epoch 170/250
# 214/214 [==============================] - 0s 2ms/step - loss: 0.0795 - mean_squared_error: 0.0066 - val_loss: 0.0790 - val_mean_squared_error: 0.0065
# Epoch 171/250
# 214/214 [==============================] - 0s 2ms/step - loss: 0.0795 - mean_squared_error: 0.0066 - val_loss: 0.0775 - val_mean_squared_error: 0.0063
# Epoch 172/250
# 214/214 [==============================] - 0s 2ms/step - loss: 0.0791 - mean_squared_error: 0.0065 - val_loss: 0.0788 - val_mean_squared_error: 0.0065
# Epoch 173/250
# 214/214 [==============================] - 0s 2ms/step - loss: 0.0794 - mean_squared_error: 0.0065 - val_loss: 0.0774 - val_mean_squared_error: 0.0063
# Epoch 174/250
# 214/214 [==============================] - 0s 2ms/step - loss: 0.0793 - mean_squared_error: 0.0065 - val_loss: 0.0777 - val_mean_squared_error: 0.0063
# Epoch 175/250
# 214/214 [==============================] - 0s 2ms/step - loss: 0.0796 - mean_squared_error: 0.0065 - val_loss: 0.0780 - val_mean_squared_error: 0.0064
# Epoch 176/250
# 214/214 [==============================] - 0s 2ms/step - loss: 0.0790 - mean_squared_error: 0.0065 - val_loss: 0.0788 - val_mean_squared_error: 0.0065
# Epoch 177/250
# 214/214 [==============================] - 0s 2ms/step - loss: 0.0793 - mean_squared_error: 0.0065 - val_loss: 0.0777 - val_mean_squared_error: 0.0063
# Epoch 178/250
# 214/214 [==============================] - 0s 2ms/step - loss: 0.0793 - mean_squared_error: 0.0065 - val_loss: 0.0779 - val_mean_squared_error: 0.0063
# Epoch 179/250
# 214/214 [==============================] - 0s 2ms/step - loss: 0.0794 - mean_squared_error: 0.0065 - val_loss: 0.0776 - val_mean_squared_error: 0.0063
# Epoch 180/250
# 214/214 [==============================] - 0s 2ms/step - loss: 0.0792 - mean_squared_error: 0.0065 - val_loss: 0.0775 - val_mean_squared_error: 0.0063
# Epoch 181/250
# 214/214 [==============================] - 0s 2ms/step - loss: 0.0795 - mean_squared_error: 0.0065 - val_loss: 0.0778 - val_mean_squared_error: 0.0063
# Epoch 182/250
# 214/214 [==============================] - 0s 2ms/step - loss: 0.0791 - mean_squared_error: 0.0065 - val_loss: 0.0779 - val_mean_squared_error: 0.0063
# Epoch 183/250
# 214/214 [==============================] - 0s 2ms/step - loss: 0.0792 - mean_squared_error: 0.0065 - val_loss: 0.0786 - val_mean_squared_error: 0.0064
# Epoch 184/250
# 214/214 [==============================] - 0s 2ms/step - loss: 0.0794 - mean_squared_error: 0.0065 - val_loss: 0.0776 - val_mean_squared_error: 0.0063
# Epoch 185/250
# 214/214 [==============================] - 0s 2ms/step - loss: 0.0795 - mean_squared_error: 0.0065 - val_loss: 0.0778 - val_mean_squared_error: 0.0063
# Epoch 186/250
# 214/214 [==============================] - 0s 2ms/step - loss: 0.0791 - mean_squared_error: 0.0065 - val_loss: 0.0777 - val_mean_squared_error: 0.0063
# Epoch 187/250
# 214/214 [==============================] - 0s 2ms/step - loss: 0.0793 - mean_squared_error: 0.0065 - val_loss: 0.0776 - val_mean_squared_error: 0.0063
# Epoch 188/250
# 214/214 [==============================] - 0s 2ms/step - loss: 0.0793 - mean_squared_error: 0.0065 - val_loss: 0.0776 - val_mean_squared_error: 0.0063
# Epoch 189/250
# 214/214 [==============================] - 0s 2ms/step - loss: 0.0792 - mean_squared_error: 0.0065 - val_loss: 0.0779 - val_mean_squared_error: 0.0064
# Epoch 190/250
# 214/214 [==============================] - 0s 2ms/step - loss: 0.0792 - mean_squared_error: 0.0065 - val_loss: 0.0790 - val_mean_squared_error: 0.0065
# Epoch 191/250
# 214/214 [==============================] - 0s 2ms/step - loss: 0.0791 - mean_squared_error: 0.0065 - val_loss: 0.0778 - val_mean_squared_error: 0.0063
# Epoch 192/250
# 214/214 [==============================] - 0s 2ms/step - loss: 0.0793 - mean_squared_error: 0.0065 - val_loss: 0.0776 - val_mean_squared_error: 0.0063
# Epoch 193/250
# 214/214 [==============================] - 0s 2ms/step - loss: 0.0789 - mean_squared_error: 0.0065 - val_loss: 0.0776 - val_mean_squared_error: 0.0063
# Epoch 194/250
# 214/214 [==============================] - 0s 2ms/step - loss: 0.0790 - mean_squared_error: 0.0064 - val_loss: 0.0781 - val_mean_squared_error: 0.0064
# Epoch 195/250
# 214/214 [==============================] - 0s 2ms/step - loss: 0.0793 - mean_squared_error: 0.0065 - val_loss: 0.0782 - val_mean_squared_error: 0.0064
# Epoch 196/250
# 214/214 [==============================] - 0s 2ms/step - loss: 0.0793 - mean_squared_error: 0.0065 - val_loss: 0.0790 - val_mean_squared_error: 0.0065
# Epoch 197/250
# 214/214 [==============================] - 0s 2ms/step - loss: 0.0790 - mean_squared_error: 0.0065 - val_loss: 0.0778 - val_mean_squared_error: 0.0063
# Epoch 198/250
# 214/214 [==============================] - 0s 2ms/step - loss: 0.0791 - mean_squared_error: 0.0065 - val_loss: 0.0778 - val_mean_squared_error: 0.0063
# Epoch 199/250
# 214/214 [==============================] - 0s 2ms/step - loss: 0.0789 - mean_squared_error: 0.0064 - val_loss: 0.0782 - val_mean_squared_error: 0.0064
# Epoch 200/250
# 214/214 [==============================] - 0s 2ms/step - loss: 0.0791 - mean_squared_error: 0.0065 - val_loss: 0.0791 - val_mean_squared_error: 0.0065
# Epoch 201/250
# 214/214 [==============================] - 0s 2ms/step - loss: 0.0788 - mean_squared_error: 0.0064 - val_loss: 0.0794 - val_mean_squared_error: 0.0066
# Epoch 202/250
# 214/214 [==============================] - 0s 2ms/step - loss: 0.0788 - mean_squared_error: 0.0064 - val_loss: 0.0794 - val_mean_squared_error: 0.0066
# Epoch 203/250
# 214/214 [==============================] - 0s 2ms/step - loss: 0.0789 - mean_squared_error: 0.0064 - val_loss: 0.0779 - val_mean_squared_error: 0.0063
# Epoch 204/250
# 214/214 [==============================] - 0s 2ms/step - loss: 0.0788 - mean_squared_error: 0.0064 - val_loss: 0.0778 - val_mean_squared_error: 0.0063
# Epoch 205/250
# 214/214 [==============================] - 0s 2ms/step - loss: 0.0789 - mean_squared_error: 0.0065 - val_loss: 0.0781 - val_mean_squared_error: 0.0064
# Epoch 206/250
# 214/214 [==============================] - 0s 2ms/step - loss: 0.0785 - mean_squared_error: 0.0064 - val_loss: 0.0776 - val_mean_squared_error: 0.0063
# Epoch 207/250
# 214/214 [==============================] - 0s 2ms/step - loss: 0.0791 - mean_squared_error: 0.0065 - val_loss: 0.0781 - val_mean_squared_error: 0.0064
# Epoch 208/250
# 214/214 [==============================] - 0s 2ms/step - loss: 0.0788 - mean_squared_error: 0.0064 - val_loss: 0.0776 - val_mean_squared_error: 0.0063
# Epoch 209/250
# 214/214 [==============================] - 0s 2ms/step - loss: 0.0790 - mean_squared_error: 0.0065 - val_loss: 0.0781 - val_mean_squared_error: 0.0064
# Epoch 210/250
# 214/214 [==============================] - 0s 2ms/step - loss: 0.0790 - mean_squared_error: 0.0065 - val_loss: 0.0778 - val_mean_squared_error: 0.0063
# Epoch 211/250
# 214/214 [==============================] - 0s 2ms/step - loss: 0.0789 - mean_squared_error: 0.0064 - val_loss: 0.0785 - val_mean_squared_error: 0.0064
# Epoch 212/250
# 214/214 [==============================] - 0s 2ms/step - loss: 0.0788 - mean_squared_error: 0.0064 - val_loss: 0.0783 - val_mean_squared_error: 0.0064
# Epoch 213/250
# 214/214 [==============================] - 0s 2ms/step - loss: 0.0789 - mean_squared_error: 0.0064 - val_loss: 0.0781 - val_mean_squared_error: 0.0064
# Epoch 214/250
# 214/214 [==============================] - 0s 2ms/step - loss: 0.0790 - mean_squared_error: 0.0065 - val_loss: 0.0777 - val_mean_squared_error: 0.0063
# Epoch 215/250
# 214/214 [==============================] - 0s 2ms/step - loss: 0.0789 - mean_squared_error: 0.0065 - val_loss: 0.0777 - val_mean_squared_error: 0.0063
# Epoch 216/250
# 214/214 [==============================] - 0s 2ms/step - loss: 0.0785 - mean_squared_error: 0.0064 - val_loss: 0.0778 - val_mean_squared_error: 0.0063
# Epoch 217/250
# 214/214 [==============================] - 1s 3ms/step - loss: 0.0790 - mean_squared_error: 0.0065 - val_loss: 0.0785 - val_mean_squared_error: 0.0065
# Epoch 218/250
# 214/214 [==============================] - 1s 3ms/step - loss: 0.0788 - mean_squared_error: 0.0064 - val_loss: 0.0779 - val_mean_squared_error: 0.0063
# Epoch 219/250
# 214/214 [==============================] - 1s 4ms/step - loss: 0.0791 - mean_squared_error: 0.0065 - val_loss: 0.0774 - val_mean_squared_error: 0.0063
# Epoch 220/250
# 214/214 [==============================] - 0s 2ms/step - loss: 0.0788 - mean_squared_error: 0.0065 - val_loss: 0.0777 - val_mean_squared_error: 0.0063
# Epoch 221/250
# 214/214 [==============================] - 0s 2ms/step - loss: 0.0787 - mean_squared_error: 0.0064 - val_loss: 0.0781 - val_mean_squared_error: 0.0064
# Epoch 222/250
# 214/214 [==============================] - 0s 2ms/step - loss: 0.0787 - mean_squared_error: 0.0064 - val_loss: 0.0794 - val_mean_squared_error: 0.0066
# Epoch 223/250
# 214/214 [==============================] - 0s 2ms/step - loss: 0.0791 - mean_squared_error: 0.0065 - val_loss: 0.0778 - val_mean_squared_error: 0.0063
# Epoch 224/250
# 214/214 [==============================] - 0s 2ms/step - loss: 0.0786 - mean_squared_error: 0.0064 - val_loss: 0.0786 - val_mean_squared_error: 0.0065
# Epoch 225/250
# 214/214 [==============================] - 0s 2ms/step - loss: 0.0789 - mean_squared_error: 0.0064 - val_loss: 0.0776 - val_mean_squared_error: 0.0063
# Epoch 226/250
# 214/214 [==============================] - 0s 2ms/step - loss: 0.0788 - mean_squared_error: 0.0064 - val_loss: 0.0779 - val_mean_squared_error: 0.0063
# Epoch 227/250
# 214/214 [==============================] - 0s 2ms/step - loss: 0.0785 - mean_squared_error: 0.0064 - val_loss: 0.0781 - val_mean_squared_error: 0.0064
# Epoch 228/250
# 214/214 [==============================] - 0s 2ms/step - loss: 0.0789 - mean_squared_error: 0.0064 - val_loss: 0.0778 - val_mean_squared_error: 0.0063
# Epoch 229/250
# 214/214 [==============================] - 0s 2ms/step - loss: 0.0785 - mean_squared_error: 0.0064 - val_loss: 0.0781 - val_mean_squared_error: 0.0064
# Epoch 230/250
# 214/214 [==============================] - 0s 2ms/step - loss: 0.0784 - mean_squared_error: 0.0064 - val_loss: 0.0783 - val_mean_squared_error: 0.0064
# Epoch 231/250
# 214/214 [==============================] - 0s 2ms/step - loss: 0.0788 - mean_squared_error: 0.0064 - val_loss: 0.0774 - val_mean_squared_error: 0.0063
# Epoch 232/250
# 214/214 [==============================] - 0s 2ms/step - loss: 0.0787 - mean_squared_error: 0.0064 - val_loss: 0.0792 - val_mean_squared_error: 0.0065
# Epoch 233/250
# 214/214 [==============================] - 1s 3ms/step - loss: 0.0787 - mean_squared_error: 0.0064 - val_loss: 0.0773 - val_mean_squared_error: 0.0063
# Epoch 234/250
# 214/214 [==============================] - 0s 2ms/step - loss: 0.0791 - mean_squared_error: 0.0065 - val_loss: 0.0781 - val_mean_squared_error: 0.0064
# Epoch 235/250
# 214/214 [==============================] - 0s 2ms/step - loss: 0.0790 - mean_squared_error: 0.0064 - val_loss: 0.0784 - val_mean_squared_error: 0.0064
# Epoch 236/250
# 214/214 [==============================] - 0s 2ms/step - loss: 0.0787 - mean_squared_error: 0.0064 - val_loss: 0.0778 - val_mean_squared_error: 0.0063
# Epoch 237/250
# 214/214 [==============================] - 0s 2ms/step - loss: 0.0786 - mean_squared_error: 0.0064 - val_loss: 0.0797 - val_mean_squared_error: 0.0066
# Epoch 238/250
# 214/214 [==============================] - 0s 2ms/step - loss: 0.0785 - mean_squared_error: 0.0064 - val_loss: 0.0778 - val_mean_squared_error: 0.0064
# Epoch 239/250
# 214/214 [==============================] - 0s 2ms/step - loss: 0.0789 - mean_squared_error: 0.0064 - val_loss: 0.0783 - val_mean_squared_error: 0.0064
# Epoch 240/250
# 214/214 [==============================] - 0s 2ms/step - loss: 0.0787 - mean_squared_error: 0.0064 - val_loss: 0.0781 - val_mean_squared_error: 0.0064
# Epoch 241/250
# 214/214 [==============================] - 0s 2ms/step - loss: 0.0786 - mean_squared_error: 0.0064 - val_loss: 0.0785 - val_mean_squared_error: 0.0064
# Epoch 242/250
# 214/214 [==============================] - 0s 2ms/step - loss: 0.0786 - mean_squared_error: 0.0064 - val_loss: 0.0783 - val_mean_squared_error: 0.0064
# Epoch 243/250
# 214/214 [==============================] - 0s 2ms/step - loss: 0.0786 - mean_squared_error: 0.0064 - val_loss: 0.0786 - val_mean_squared_error: 0.0065
# Epoch 244/250
# 214/214 [==============================] - 0s 2ms/step - loss: 0.0786 - mean_squared_error: 0.0064 - val_loss: 0.0784 - val_mean_squared_error: 0.0064
# Epoch 245/250
# 214/214 [==============================] - 0s 2ms/step - loss: 0.0785 - mean_squared_error: 0.0064 - val_loss: 0.0781 - val_mean_squared_error: 0.0064
# Epoch 246/250
# 214/214 [==============================] - 0s 2ms/step - loss: 0.0790 - mean_squared_error: 0.0065 - val_loss: 0.0785 - val_mean_squared_error: 0.0065
# Epoch 247/250
# 214/214 [==============================] - 0s 2ms/step - loss: 0.0787 - mean_squared_error: 0.0064 - val_loss: 0.0782 - val_mean_squared_error: 0.0064
# Epoch 248/250
# 214/214 [==============================] - 0s 2ms/step - loss: 0.0783 - mean_squared_error: 0.0064 - val_loss: 0.0782 - val_mean_squared_error: 0.0064
# Epoch 249/250
# 214/214 [==============================] - 0s 2ms/step - loss: 0.0784 - mean_squared_error: 0.0064 - val_loss: 0.0786 - val_mean_squared_error: 0.0065
# Epoch 250/250
# 214/214 [==============================] - 0s 2ms/step - loss: 0.0788 - mean_squared_error: 0.0064 - val_loss: 0.0784 - val_mean_squared_error: 0.0064

# %%
from sklearn.metrics import r2_score
##### Evaluating model performance on validation set #####
prediction = model.predict(X_test)

# calculating the accuracy on validation set
r2_score(y_test, prediction)
# Out:
# 0.5977613519319616

# %% [markdown]
# ##4.Test Data Preprocessing

# %%
test_data = 'https://raw.githubusercontent.com/DiwakarBasnet/Neural_Network/main/Sales_Prediction/test_file.csv'
check = pd.read_csv(test_data)

# %%
check.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                   976
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  1606
# Outlet_Location_Type            0
# Outlet_Type                     0
# dtype: int64

# %% [markdown]
# ###I. Filling Missing Values

# %%
# filling missing values of continuous data with mean
check['Item_Weight'].fillna(check['Item_Weight'].mean(), inplace=True)

# filling missing values of categorical data with mode
check['Outlet_Size'].fillna(check['Outlet_Size'].mode()[0], inplace=True)

# %%
# checking missing values after imputation
check.isnull().sum()
# Out:
# Item_Identifier              0
# Item_Weight                  0
# Item_Fat_Content             0
# Item_Visibility              0
# Item_Type                    0
# Item_MRP                     0
# Outlet_Identifier            0
# Outlet_Establishment_Year    0
# Outlet_Size                  0
# Outlet_Location_Type         0
# Outlet_Type                  0
# dtype: int64

# %% [markdown]
# ###II. Converting categorical data to numerical

# %%
check['Item_Fat_Content'] = check['Item_Fat_Content'].map({'LF':0, 'Low Fat':0, 'low fat':0, 'Regular':1, 'reg':1})
check['Item_Type'] = check['Item_Type'].map({'Fruits and Vegetables':0, 'Snack Foods':1, 'Household':2, 'Frozen Foods':3, 'Dairy':4,
                                                 'Canned':5, 'Baking Goods':6, 'Health and Hygiene':7, 'Soft Drinks':8, 'Meat':9,
                                                 'Breads':10, 'Hard Drinks':11, 'Others':12, 'Starchy Foods':13, 'Breakfast':14, 'Seafood':15})
check['Outlet_Size'] = check['Outlet_Size'].map({'Small':0, 'Medium':1, 'High':2})
check['Outlet_Location_Type'] = check['Outlet_Location_Type'].map({'Tier 1':0, 'Tier 2':1, 'Tier 3':2})
check['Outlet_Type'] = check['Outlet_Type'].map({'Grocery Store':0, 'Supermarket Type1':1, 'Supermarket Type2':2, 'Supermarket Type3':3})

# %%
check.head()
# Out:
#   Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  Item_Type  \
# 0           FDW58    20.750000                 0         0.007565          1
# 1           FDW14     8.300000                 1         0.038428          4
# 2           NCN55    14.600000                 0         0.099575         12
# 3           FDQ58     7.315000                 0         0.015388          1
# 4           FDY38    12.695633                 1         0.118599          4
#
#    Item_MRP Outlet_Identifier  Outlet_Establishment_Year  Outlet_Size  \
# 0  107.8622            OUT049                       1999            1
# 1   87.3198            OUT017                       2007            1
# 2  241.7538            OUT010                       1998            1
# 3  155.0340            OUT017                       2007            1
# 4  234.2300            OUT027                       1985            1
#
#    Outlet_Location_Type  Outlet_Type
# 0                     0            1
# 1                     1            1
# 2                     2            0
# 3                     1            1
# 4                     2            3

# %% [markdown]
# ###III. Normalization

# %%
# bringing the variables in the range of 0 to 1
for i in check.columns[1:6]:
  check[i] = (check[i] - check[i].min()) / (check[i].max() - check[i].min())

for i in check.columns[7:]:
  check[i] = (check[i] - check[i].min()) / (check[i].max() - check[i].min())

# %%
check.to_csv('normalized_test.csv', index=False)

# %%
data_test = pd.read_csv('normalized_test.csv')

# %%
# removing Item_Identifier and Outlet_Identifier
new_test_data = data_test.drop(['Item_Identifier', 'Outlet_Identifier'], axis=1)

# %%
new_test_data.head()
# Out:
#    Item_Weight  Item_Fat_Content  Item_Visibility  Item_Type  Item_MRP  \
# 0     0.964275               0.0         0.023374   0.066667  0.323413
# 1     0.222983               1.0         0.118737   0.266667  0.235849
# 2     0.598095               0.0         0.307674   0.800000  0.894140
# 3     0.164335               0.0         0.047548   0.066667  0.524488
# 4     0.484706               1.0         0.366458   0.266667  0.862069
#
#    Outlet_Establishment_Year  Outlet_Size  Outlet_Location_Type  Outlet_Type
# 0                   0.583333          0.5                   0.0     0.333333
# 1                   0.916667          0.5                   0.5     0.333333
# 2                   0.541667          0.5                   1.0     0.000000
# 3                   0.916667          0.5                   0.5     0.333333
# 4                   0.000000          0.5                   1.0     1.000000

# %%
pred = model.predict(new_test_data)

# %%
df = pd.DataFrame()
df['Item_Identifier'] = data_test['Item_Identifier']
df['Outlet_Identifier'] = data_test['Outlet_Identifier']
df['Item_Outlet_Sales']= pred

df
# Out:
#      Item_Identifier Outlet_Identifier  Item_Outlet_Sales
# 0              FDW58            OUT049           0.111780
# 1              FDW14            OUT017           0.096146
# 2              NCN55            OUT010           0.040060
# 3              FDQ58            OUT017           0.225286
# 4              FDY38            OUT027           0.463918
# ...              ...               ...                ...
# 5676           FDB58            OUT046           0.169242
# 5677           FDD47            OUT018           0.201875
# 5678           NCO17            OUT045           0.155101
# 5679           FDJ26            OUT017           0.363713
# 5680           FDU37            OUT045           0.077046
#
# [5681 rows x 3 columns]

# %%
df.to_csv('solution.csv', index=False)
