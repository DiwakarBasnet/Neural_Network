# %% [markdown]
# <a href="https://colab.research.google.com/github/DiwakarBasnet/Neural_Network/blob/main/Sales.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Big Mart Sales Prediction
# -> Multilayer Perceptron (MLP)

# %%
# importing required libraries
import pandas as pd
import numpy as np
import sklearn
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# reading dataset
train_data = 'https://raw.githubusercontent.com/DiwakarBasnet/Neural_Network/main/Sales_Prediction/train_file.csv'
dataset = pd.read_csv(train_data)

# %% [markdown]
# # ##1.Data Preprocessing

# %%
dataset.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# 2                       1999      Medium               Tier 1
# 3                       1998         NaN               Tier 3
# 4                       1987        High               Tier 3
#
#          Outlet_Type  Item_Outlet_Sales
# 0  Supermarket Type1          3735.1380
# 1  Supermarket Type2           443.4228
# 2  Supermarket Type1          2097.2700
# 3      Grocery Store           732.3800
# 4  Supermarket Type1           994.7052

# %%
# checking missing values in table
dataset.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
dataset.dtypes
# Out:
# Item_Identifier               object
# Item_Weight                  float64
# Item_Fat_Content              object
# Item_Visibility              float64
# Item_Type                     object
# Item_MRP                     float64
# Outlet_Identifier             object
# Outlet_Establishment_Year      int64
# Outlet_Size                   object
# Outlet_Location_Type          object
# Outlet_Type                   object
# Item_Outlet_Sales            float64
# dtype: object

# %% [markdown]
# ###I. Filling missing values

# %%
# filling missing values of continuous data with mean
dataset['Item_Weight'].fillna(dataset['Item_Weight'].mean(), inplace=True)

# filling missing values of categorical data with mode
dataset['Outlet_Size'].fillna(dataset['Outlet_Size'].mode()[0], inplace=True)

# %%
# checking missing values after imputation
dataset.isnull().sum()
# Out:
# Item_Identifier              0
# Item_Weight                  0
# Item_Fat_Content             0
# Item_Visibility              0
# Item_Type                    0
# Item_MRP                     0
# Outlet_Identifier            0
# Outlet_Establishment_Year    0
# Outlet_Size                  0
# Outlet_Location_Type         0
# Outlet_Type                  0
# Item_Outlet_Sales            0
# dtype: int64

# %% [markdown]
# ###II. Converting categorical data to numbers

# %%
print(dataset.Item_Fat_Content.value_counts())
print(dataset.Item_Type.value_counts())
print(dataset.Outlet_Size.value_counts())
print(dataset.Outlet_Location_Type.value_counts())
print(dataset.Outlet_Type.value_counts())
# Out:
# Low Fat    5089
# Regular    2889
# LF          316
# reg         117
# low fat     112
# Name: Item_Fat_Content, dtype: int64
# Fruits and Vegetables    1232
# Snack Foods              1200
# Household                 910
# Frozen Foods              856
# Dairy                     682
# Canned                    649
# Baking Goods              648
# Health and Hygiene        520
# Soft Drinks               445
# Meat                      425
# Breads                    251
# Hard Drinks               214
# Others                    169
# Starchy Foods             148
# Breakfast                 110
# Seafood                    64
# Name: Item_Type, dtype: int64
# Medium    5203
# Small     2388
# High       932
# Name: Outlet_Size, dtype: int64
# Tier 3    3350
# Tier 2    2785
# Tier 1    2388
# Name: Outlet_Location_Type, dtype: int64
# Supermarket Type1    5577
# Grocery Store        1083
# Supermarket Type3     935
# Supermarket Type2     928
# Name: Outlet_Type, dtype: int64

# %%
dataset['Item_Fat_Content'] = dataset['Item_Fat_Content'].map({'LF':0, 'Low Fat':0, 'low fat':0, 'Regular':1, 'reg':1})
dataset['Item_Type'] = dataset['Item_Type'].map({'Fruits and Vegetables':0, 'Snack Foods':1, 'Household':2, 'Frozen Foods':3, 'Dairy':4,
                                                 'Canned':5, 'Baking Goods':6, 'Health and Hygiene':7, 'Soft Drinks':8, 'Meat':9,
                                                 'Breads':10, 'Hard Drinks':11, 'Others':12, 'Starchy Foods':13, 'Breakfast':14, 'Seafood':15})
dataset['Outlet_Size'] = dataset['Outlet_Size'].map({'Small':0, 'Medium':1, 'High':2})
dataset['Outlet_Location_Type'] = dataset['Outlet_Location_Type'].map({'Tier 1':0, 'Tier 2':1, 'Tier 3':2})
dataset['Outlet_Type'] = dataset['Outlet_Type'].map({'Grocery Store':0, 'Supermarket Type1':1, 'Supermarket Type2':2, 'Supermarket Type3':3})

# %%
dataset.head()
# Out:
#   Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  Item_Type  \
# 0           FDA15         9.30                 0         0.016047          4
# 1           DRC01         5.92                 1         0.019278          8
# 2           FDN15        17.50                 0         0.016760          9
# 3           FDX07        19.20                 1         0.000000          0
# 4           NCD19         8.93                 0         0.000000          2
#
#    Item_MRP Outlet_Identifier  Outlet_Establishment_Year  Outlet_Size  \
# 0  249.8092            OUT049                       1999            1
# 1   48.2692            OUT018                       2009            1
# 2  141.6180            OUT049                       1999            1
# 3  182.0950            OUT010                       1998            1
# 4   53.8614            OUT013                       1987            2
#
#    Outlet_Location_Type  Outlet_Type  Item_Outlet_Sales
# 0                     0            1          3735.1380
# 1                     2            2           443.4228
# 2                     0            1          2097.2700
# 3                     2            0           732.3800
# 4                     2            1           994.7052

# %% [markdown]
# ###III. Normalization

# %%
# bringing the variables in the range of 0 to 1
for i in dataset.columns[1:6]:
  dataset[i] = (dataset[i] - dataset[i].min()) / (dataset[i].max() - dataset[i].min())

for i in dataset.columns[7:]:
  dataset[i] = (dataset[i] - dataset[i].min()) / (dataset[i].max() - dataset[i].min())

# %%
dataset.head()
# Out:
#   Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  Item_Type  \
# 0           FDA15     0.282525               0.0         0.048866   0.266667
# 1           DRC01     0.081274               1.0         0.058705   0.533333
# 2           FDN15     0.770765               0.0         0.051037   0.600000
# 3           FDX07     0.871986               1.0         0.000000   0.000000
# 4           NCD19     0.260494               0.0         0.000000   0.133333
#
#    Item_MRP Outlet_Identifier  Outlet_Establishment_Year  Outlet_Size  \
# 0  0.927507            OUT049                   0.583333          0.5
# 1  0.072068            OUT018                   1.000000          0.5
# 2  0.468288            OUT049                   0.583333          0.5
# 3  0.640093            OUT010                   0.541667          0.5
# 4  0.095805            OUT013                   0.083333          1.0
#
#    Outlet_Location_Type  Outlet_Type  Item_Outlet_Sales
# 0                   0.0     0.333333           0.283587
# 1                   1.0     0.666667           0.031419
# 2                   0.0     0.333333           0.158115
# 3                   1.0     0.000000           0.053555
# 4                   1.0     0.333333           0.073651

# %%
dataset.to_csv('normalized_train.csv', index=False)

# %%
data = pd.read_csv('normalized_train.csv')

# %%
# removing Item_Identifier and Outlet_Identifier
data = data.drop(['Item_Identifier', 'Outlet_Identifier'], axis=1)
data.head()
# Out:
#    Item_Weight  Item_Fat_Content  Item_Visibility  Item_Type  Item_MRP  \
# 0     0.282525               0.0         0.048866   0.266667  0.927507
# 1     0.081274               1.0         0.058705   0.533333  0.072068
# 2     0.770765               0.0         0.051037   0.600000  0.468288
# 3     0.871986               1.0         0.000000   0.000000  0.640093
# 4     0.260494               0.0         0.000000   0.133333  0.095805
#
#    Outlet_Establishment_Year  Outlet_Size  Outlet_Location_Type  Outlet_Type  \
# 0                   0.583333          0.5                   0.0     0.333333
# 1                   1.000000          0.5                   1.0     0.666667
# 2                   0.583333          0.5                   0.0     0.333333
# 3                   0.541667          0.5                   1.0     0.000000
# 4                   0.083333          1.0                   1.0     0.333333
#
#    Item_Outlet_Sales
# 0           0.283587
# 1           0.031419
# 2           0.158115
# 3           0.053555
# 4           0.073651

# %%
# storing all the features as X
X = data.drop('Item_Outlet_Sales', axis=1)
# storing target as y
y = data['Item_Outlet_Sales']
# shape of X and y
X.shape, y.shape
# Out:
# ((8523, 9), (8523,))

# %%
##### creating training and validation set #####
# random state to regenerate same train and validation set
# test size 0.2 will keep 20% data in validation and 80% train set

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=10, test_size=0.2)

(X_train.shape, y_train.shape), (X_test.shape, y_test.shape)
# Out:
# (((6818, 9), (6818,)), ((1705, 9), (1705,)))

# %% [markdown]
# #2.Defining the architecture of model

# %%
import keras
import tensorflow as tf
from keras.models import Sequential
from keras.layers import InputLayer, Dense

# %%
# defining input neurons
input_neurons = X_train.shape[1]
# defining output neurons
output_neurons = 1
# defining hidden layers and neurons in each layer
num_of_hidden_layers = 3
neuron_hidden_layer_1 = 20
neuron_hidden_layer_2 = 10
neuron_hidden_layer_3 = 5

# %%
from logging import INFO
model = Sequential()
model.add(InputLayer(input_shape=(input_neurons,)))
model.add(Dense(units=neuron_hidden_layer_1, activation='relu'))
model.add(Dense(units=neuron_hidden_layer_2, activation='relu'))
model.add(Dense(units=neuron_hidden_layer_3, activation='relu'))
model.add(Dense(units=output_neurons, activation='linear'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 20)                200
#
#  dense_1 (Dense)             (None, 10)                210
#
#  dense_2 (Dense)             (None, 5)                 55
#
#  dense_3 (Dense)             (None, 1)                 6
#
# =================================================================
# Total params: 471
# Trainable params: 471
# Non-trainable params: 0
# _________________________________________________________________

# %%
##### Compiling the model #####
model.compile(loss='mean_squared_error', optimizer='Adam', metrics=['accuracy'])

# %% [markdown]
# #3.Train model

# %%
model_history = model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=100)
# Out:
# Epoch 1/100
# 214/214 [==============================] - 3s 7ms/step - loss: 0.0095 - accuracy: 1.4667e-04 - val_loss: 0.0080 - val_accuracy: 5.8651e-04
# Epoch 2/100
# 214/214 [==============================] - 1s 5ms/step - loss: 0.0078 - accuracy: 1.4667e-04 - val_loss: 0.0074 - val_accuracy: 5.8651e-04
# Epoch 3/100
# 214/214 [==============================] - 1s 5ms/step - loss: 0.0075 - accuracy: 1.4667e-04 - val_loss: 0.0073 - val_accuracy: 5.8651e-04
# Epoch 4/100
# 214/214 [==============================] - 1s 5ms/step - loss: 0.0073 - accuracy: 1.4667e-04 - val_loss: 0.0073 - val_accuracy: 5.8651e-04
# Epoch 5/100
# 214/214 [==============================] - 1s 4ms/step - loss: 0.0071 - accuracy: 1.4667e-04 - val_loss: 0.0071 - val_accuracy: 5.8651e-04
# Epoch 6/100
# 214/214 [==============================] - 1s 5ms/step - loss: 0.0071 - accuracy: 1.4667e-04 - val_loss: 0.0072 - val_accuracy: 5.8651e-04
# Epoch 7/100
# 214/214 [==============================] - 1s 5ms/step - loss: 0.0071 - accuracy: 1.4667e-04 - val_loss: 0.0069 - val_accuracy: 5.8651e-04
# Epoch 8/100
# 214/214 [==============================] - 1s 5ms/step - loss: 0.0070 - accuracy: 1.4667e-04 - val_loss: 0.0069 - val_accuracy: 5.8651e-04
# Epoch 9/100
# 214/214 [==============================] - 1s 7ms/step - loss: 0.0070 - accuracy: 1.4667e-04 - val_loss: 0.0069 - val_accuracy: 5.8651e-04
# Epoch 10/100
# 214/214 [==============================] - 2s 7ms/step - loss: 0.0070 - accuracy: 1.4667e-04 - val_loss: 0.0069 - val_accuracy: 5.8651e-04
# Epoch 11/100
# 214/214 [==============================] - 1s 7ms/step - loss: 0.0069 - accuracy: 1.4667e-04 - val_loss: 0.0068 - val_accuracy: 5.8651e-04
# Epoch 12/100
# 214/214 [==============================] - 1s 6ms/step - loss: 0.0069 - accuracy: 1.4667e-04 - val_loss: 0.0068 - val_accuracy: 5.8651e-04
# Epoch 13/100
# 214/214 [==============================] - 1s 4ms/step - loss: 0.0069 - accuracy: 1.4667e-04 - val_loss: 0.0069 - val_accuracy: 5.8651e-04
# Epoch 14/100
# 214/214 [==============================] - 1s 6ms/step - loss: 0.0069 - accuracy: 1.4667e-04 - val_loss: 0.0069 - val_accuracy: 5.8651e-04
# Epoch 15/100
# 214/214 [==============================] - 1s 7ms/step - loss: 0.0069 - accuracy: 1.4667e-04 - val_loss: 0.0068 - val_accuracy: 5.8651e-04
# Epoch 16/100
# 214/214 [==============================] - 1s 5ms/step - loss: 0.0069 - accuracy: 1.4667e-04 - val_loss: 0.0068 - val_accuracy: 5.8651e-04
# Epoch 17/100
# 214/214 [==============================] - 1s 4ms/step - loss: 0.0069 - accuracy: 1.4667e-04 - val_loss: 0.0075 - val_accuracy: 5.8651e-04
# Epoch 18/100
# 214/214 [==============================] - 1s 6ms/step - loss: 0.0069 - accuracy: 1.4667e-04 - val_loss: 0.0069 - val_accuracy: 5.8651e-04
# Epoch 19/100
# 214/214 [==============================] - 1s 5ms/step - loss: 0.0068 - accuracy: 1.4667e-04 - val_loss: 0.0071 - val_accuracy: 5.8651e-04
# Epoch 20/100
# 214/214 [==============================] - 1s 4ms/step - loss: 0.0069 - accuracy: 1.4667e-04 - val_loss: 0.0068 - val_accuracy: 5.8651e-04
# Epoch 21/100
# 214/214 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 1.4667e-04 - val_loss: 0.0068 - val_accuracy: 5.8651e-04
# Epoch 59/100
# 214/214 [==============================] - 1s 3ms/step - loss: 0.0068 - accuracy: 1.4667e-04 - val_loss: 0.0067 - val_accuracy: 5.8651e-04
# Epoch 60/100
# 214/214 [==============================] - 1s 2ms/step - loss: 0.0068 - accuracy: 1.4667e-04 - val_loss: 0.0067 - val_accuracy: 5.8651e-04
# Epoch 61/100
# 214/214 [==============================] - 1s 2ms/step - loss: 0.0068 - accuracy: 1.4667e-04 - val_loss: 0.0068 - val_accuracy: 5.8651e-04
# Epoch 62/100
# 214/214 [==============================] - 1s 3ms/step - loss: 0.0068 - accuracy: 1.4667e-04 - val_loss: 0.0068 - val_accuracy: 5.8651e-04
# Epoch 63/100
# 214/214 [==============================] - 1s 2ms/step - loss: 0.0068 - accuracy: 1.4667e-04 - val_loss: 0.0067 - val_accuracy: 5.8651e-04
# Epoch 64/100
# 214/214 [==============================] - 1s 2ms/step - loss: 0.0068 - accuracy: 1.4667e-04 - val_loss: 0.0067 - val_accuracy: 5.8651e-04
# Epoch 65/100
# 214/214 [==============================] - 1s 3ms/step - loss: 0.0068 - accuracy: 1.4667e-04 - val_loss: 0.0067 - val_accuracy: 5.8651e-04
# Epoch 66/100
# 214/214 [==============================] - 1s 3ms/step - loss: 0.0068 - accuracy: 1.4667e-04 - val_loss: 0.0070 - val_accuracy: 5.8651e-04
# Epoch 67/100
# 214/214 [==============================] - 1s 3ms/step - loss: 0.0068 - accuracy: 1.4667e-04 - val_loss: 0.0067 - val_accuracy: 5.8651e-04
# Epoch 68/100
# 214/214 [==============================] - 1s 2ms/step - loss: 0.0068 - accuracy: 1.4667e-04 - val_loss: 0.0068 - val_accuracy: 5.8651e-04
# Epoch 69/100
# 214/214 [==============================] - 1s 3ms/step - loss: 0.0068 - accuracy: 1.4667e-04 - val_loss: 0.0067 - val_accuracy: 5.8651e-04
# Epoch 70/100
# 214/214 [==============================] - 1s 2ms/step - loss: 0.0068 - accuracy: 1.4667e-04 - val_loss: 0.0068 - val_accuracy: 5.8651e-04
# Epoch 71/100
# 214/214 [==============================] - 0s 2ms/step - loss: 0.0067 - accuracy: 1.4667e-04 - val_loss: 0.0068 - val_accuracy: 5.8651e-04
# Epoch 72/100
# 214/214 [==============================] - 1s 3ms/step - loss: 0.0068 - accuracy: 1.4667e-04 - val_loss: 0.0067 - val_accuracy: 5.8651e-04
# Epoch 73/100
# 214/214 [==============================] - 1s 2ms/step - loss: 0.0067 - accuracy: 1.4667e-04 - val_loss: 0.0067 - val_accuracy: 5.8651e-04
# Epoch 74/100
# 214/214 [==============================] - 1s 3ms/step - loss: 0.0068 - accuracy: 1.4667e-04 - val_loss: 0.0067 - val_accuracy: 5.8651e-04
# Epoch 75/100
# 214/214 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 1.4667e-04 - val_loss: 0.0068 - val_accuracy: 5.8651e-04
# Epoch 76/100
# 214/214 [==============================] - 1s 2ms/step - loss: 0.0068 - accuracy: 1.4667e-04 - val_loss: 0.0069 - val_accuracy: 5.8651e-04
# Epoch 77/100
# 214/214 [==============================] - 1s 2ms/step - loss: 0.0068 - accuracy: 1.4667e-04 - val_loss: 0.0068 - val_accuracy: 5.8651e-04
# Epoch 78/100
# 214/214 [==============================] - 0s 2ms/step - loss: 0.0067 - accuracy: 1.4667e-04 - val_loss: 0.0067 - val_accuracy: 5.8651e-04
# Epoch 79/100
# 214/214 [==============================] - 0s 2ms/step - loss: 0.0067 - accuracy: 1.4667e-04 - val_loss: 0.0068 - val_accuracy: 5.8651e-04
# Epoch 80/100
# 214/214 [==============================] - 1s 2ms/step - loss: 0.0068 - accuracy: 1.4667e-04 - val_loss: 0.0067 - val_accuracy: 5.8651e-04
# Epoch 81/100
# 214/214 [==============================] - 1s 2ms/step - loss: 0.0068 - accuracy: 1.4667e-04 - val_loss: 0.0067 - val_accuracy: 5.8651e-04
# Epoch 82/100
# 214/214 [==============================] - 1s 2ms/step - loss: 0.0068 - accuracy: 1.4667e-04 - val_loss: 0.0068 - val_accuracy: 5.8651e-04
# Epoch 83/100
# 214/214 [==============================] - 1s 3ms/step - loss: 0.0067 - accuracy: 1.4667e-04 - val_loss: 0.0072 - val_accuracy: 5.8651e-04
# Epoch 84/100
# 214/214 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 1.4667e-04 - val_loss: 0.0067 - val_accuracy: 5.8651e-04
# Epoch 85/100
# 214/214 [==============================] - 1s 2ms/step - loss: 0.0068 - accuracy: 1.4667e-04 - val_loss: 0.0068 - val_accuracy: 5.8651e-04
# Epoch 86/100
# 214/214 [==============================] - 1s 2ms/step - loss: 0.0067 - accuracy: 1.4667e-04 - val_loss: 0.0068 - val_accuracy: 5.8651e-04
# Epoch 87/100
# 214/214 [==============================] - 1s 3ms/step - loss: 0.0068 - accuracy: 1.4667e-04 - val_loss: 0.0068 - val_accuracy: 5.8651e-04
# Epoch 88/100
# 214/214 [==============================] - 1s 3ms/step - loss: 0.0068 - accuracy: 1.4667e-04 - val_loss: 0.0068 - val_accuracy: 5.8651e-04
# Epoch 89/100
# 214/214 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 1.4667e-04 - val_loss: 0.0070 - val_accuracy: 5.8651e-04
# Epoch 90/100
# 214/214 [==============================] - 1s 3ms/step - loss: 0.0068 - accuracy: 1.4667e-04 - val_loss: 0.0067 - val_accuracy: 5.8651e-04
# Epoch 91/100
# 214/214 [==============================] - 1s 3ms/step - loss: 0.0067 - accuracy: 1.4667e-04 - val_loss: 0.0070 - val_accuracy: 5.8651e-04
# Epoch 92/100
# 214/214 [==============================] - 1s 3ms/step - loss: 0.0068 - accuracy: 1.4667e-04 - val_loss: 0.0067 - val_accuracy: 5.8651e-04
# Epoch 93/100
# 214/214 [==============================] - 1s 3ms/step - loss: 0.0067 - accuracy: 1.4667e-04 - val_loss: 0.0067 - val_accuracy: 5.8651e-04
# Epoch 94/100
# 214/214 [==============================] - 1s 3ms/step - loss: 0.0067 - accuracy: 1.4667e-04 - val_loss: 0.0067 - val_accuracy: 5.8651e-04
# Epoch 95/100
# 214/214 [==============================] - 1s 3ms/step - loss: 0.0068 - accuracy: 1.4667e-04 - val_loss: 0.0067 - val_accuracy: 5.8651e-04
# Epoch 96/100
# 214/214 [==============================] - 1s 3ms/step - loss: 0.0068 - accuracy: 1.4667e-04 - val_loss: 0.0071 - val_accuracy: 5.8651e-04
# Epoch 97/100
# 214/214 [==============================] - 1s 3ms/step - loss: 0.0068 - accuracy: 1.4667e-04 - val_loss: 0.0068 - val_accuracy: 5.8651e-04
# Epoch 98/100
# 214/214 [==============================] - 1s 2ms/step - loss: 0.0068 - accuracy: 1.4667e-04 - val_loss: 0.0067 - val_accuracy: 5.8651e-04
# Epoch 99/100
# 214/214 [==============================] - 1s 3ms/step - loss: 0.0067 - accuracy: 1.4667e-04 - val_loss: 0.0068 - val_accuracy: 5.8651e-04
# Epoch 100/100
# 214/214 [==============================] - 1s 3ms/step - loss: 0.0067 - accuracy: 1.4667e-04 - val_loss: 0.0071 - val_accuracy: 5.8651e-04

# %%
##### Evaluating model performance on validation set #####
prediction = model.predict(X_test)

# calculating the accuracy on validation set
r2_score(y_test, prediction)
# Out:
# 0.594818287962477

# %% [markdown]
# #4.Test Data Preprocessing

# %%
# reading dataset
test_data = 'https://raw.githubusercontent.com/DiwakarBasnet/Neural_Network/main/Sales_Prediction/test_file.csv'
check = pd.read_csv(test_data)

# %%
check.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility    Item_Type  \
# 0           FDW58       20.750          Low Fat         0.007565  Snack Foods
# 1           FDW14        8.300              reg         0.038428        Dairy
# 2           NCN55       14.600          Low Fat         0.099575       Others
# 3           FDQ58        7.315          Low Fat         0.015388  Snack Foods
# 4           FDY38          NaN          Regular         0.118599        Dairy
#
#    Item_MRP Outlet_Identifier  Outlet_Establishment_Year Outlet_Size  \
# 0  107.8622            OUT049                       1999      Medium
# 1   87.3198            OUT017                       2007         NaN
# 2  241.7538            OUT010                       1998         NaN
# 3  155.0340            OUT017                       2007         NaN
# 4  234.2300            OUT027                       1985      Medium
#
#   Outlet_Location_Type        Outlet_Type
# 0               Tier 1  Supermarket Type1
# 1               Tier 2  Supermarket Type1
# 2               Tier 3      Grocery Store
# 3               Tier 2  Supermarket Type1
# 4               Tier 3  Supermarket Type3

# %%
check.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                   976
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  1606
# Outlet_Location_Type            0
# Outlet_Type                     0
# dtype: int64

# %%
check.shape
# Out:
# (5681, 11)

# %% [markdown]
# ##I. Filling Missing Values

# %%
# filling missing values of continuous data with mean
check['Item_Weight'].fillna(check['Item_Weight'].mean(), inplace=True)

# filling missing values of categorical data with mode
check['Outlet_Size'].fillna(check['Outlet_Size'].mode()[0], inplace=True)

# %%
# checking missing values after imputation
check.isnull().sum()
# Out:
# Item_Identifier              0
# Item_Weight                  0
# Item_Fat_Content             0
# Item_Visibility              0
# Item_Type                    0
# Item_MRP                     0
# Outlet_Identifier            0
# Outlet_Establishment_Year    0
# Outlet_Size                  0
# Outlet_Location_Type         0
# Outlet_Type                  0
# dtype: int64

# %% [markdown]
# ##II. Converting categorical data to numbers

# %%
check['Item_Fat_Content'] = check['Item_Fat_Content'].map({'LF':0, 'Low Fat':0, 'low fat':0, 'Regular':1, 'reg':1})
check['Item_Type'] = check['Item_Type'].map({'Fruits and Vegetables':0, 'Snack Foods':1, 'Household':2, 'Frozen Foods':3, 'Dairy':4,
                                                 'Canned':5, 'Baking Goods':6, 'Health and Hygiene':7, 'Soft Drinks':8, 'Meat':9,
                                                 'Breads':10, 'Hard Drinks':11, 'Others':12, 'Starchy Foods':13, 'Breakfast':14, 'Seafood':15})
check['Outlet_Size'] = check['Outlet_Size'].map({'Small':0, 'Medium':1, 'High':2})
check['Outlet_Location_Type'] = check['Outlet_Location_Type'].map({'Tier 1':0, 'Tier 2':1, 'Tier 3':2})
check['Outlet_Type'] = check['Outlet_Type'].map({'Grocery Store':0, 'Supermarket Type1':1, 'Supermarket Type2':2, 'Supermarket Type3':3})

# %%
check.head()
# Out:
#   Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  Item_Type  \
# 0           FDW58    20.750000                 0         0.007565          1
# 1           FDW14     8.300000                 1         0.038428          4
# 2           NCN55    14.600000                 0         0.099575         12
# 3           FDQ58     7.315000                 0         0.015388          1
# 4           FDY38    12.695633                 1         0.118599          4
#
#    Item_MRP Outlet_Identifier  Outlet_Establishment_Year  Outlet_Size  \
# 0  107.8622            OUT049                       1999            1
# 1   87.3198            OUT017                       2007            1
# 2  241.7538            OUT010                       1998            1
# 3  155.0340            OUT017                       2007            1
# 4  234.2300            OUT027                       1985            1
#
#    Outlet_Location_Type  Outlet_Type
# 0                     0            1
# 1                     1            1
# 2                     2            0
# 3                     1            1
# 4                     2            3

# %% [markdown]
# ##III. Normalization

# %%
# bringing the variables in the range of 0 to 1
for i in check.columns[1:6]:
  check[i] = (check[i] - check[i].min()) / (check[i].max() - check[i].min())

for i in check.columns[7:]:
  check[i] = (check[i] - check[i].min()) / (check[i].max() - check[i].min())

# %%
check.to_csv('normalized_test.csv', index=False)

# %%
data_test = pd.read_csv('normalized_test.csv')

# %%
# removing Item_Identifier and Outlet_Identifier
new_test_data = data_test.drop(['Item_Identifier', 'Outlet_Identifier'], axis=1)

# %%
new_test_data.head()
# Out:
#    Item_Weight  Item_Fat_Content  Item_Visibility  Item_Type  Item_MRP  \
# 0     0.964275               0.0         0.023374   0.066667  0.323413
# 1     0.222983               1.0         0.118737   0.266667  0.235849
# 2     0.598095               0.0         0.307674   0.800000  0.894140
# 3     0.164335               0.0         0.047548   0.066667  0.524488
# 4     0.484706               1.0         0.366458   0.266667  0.862069
#
#    Outlet_Establishment_Year  Outlet_Size  Outlet_Location_Type  Outlet_Type
# 0                   0.583333          0.5                   0.0     0.333333
# 1                   0.916667          0.5                   0.5     0.333333
# 2                   0.541667          0.5                   1.0     0.000000
# 3                   0.916667          0.5                   0.5     0.333333
# 4                   0.000000          0.5                   1.0     1.000000

# %%
pred = model.predict(new_test_data)

# %%
check_data = {'Item_Identifier': data_test['Item_Identifier'], 'Outlet_Identifier': data_test['Outlet_Identifier'], 'Item_Outlet_Sales': pred.flatten()}
df = pd.DataFrame(check_data)

# %%
df.head()
# Out:
#   Item_Identifier Outlet_Identifier  Item_Outlet_Sales
# 0           FDW58            OUT049           0.110245
# 1           FDW14            OUT017           0.076428
# 2           NCN55            OUT010           0.038280
# 3           FDQ58            OUT017           0.170905
# 4           FDY38            OUT027           0.415146

# %%
df.to_csv('solution.csv', index=False)
